# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
train = pd.read_csv('Data/training_set_features.csv',index_col='respondent_id')
labels = pd.read_csv('Data/training_set_labels.csv',index_col='respondent_id')

# %%
joined_df = train.join(labels)

# %%
seasonal_df = joined_df.drop(columns=[col for col in joined_df.columns if 'h1n1' in col],index=1).reset_index()
seasonal_df = seasonal_df.drop(columns=['employment_industry','employment_occupation'])

# %%
float_columns = seasonal_df.select_dtypes(include=['float64']).columns 
object_columns = seasonal_df.select_dtypes(include=['object']).columns 
int_columns = seasonal_df.select_dtypes(include=['int64']).columns

# %%
df_clean_v1 = seasonal_df.dropna(subset=object_columns)

for col in float_columns:
    median = df_clean_v1[col].median()
    df_clean_v1[col].fillna(value=median, inplace= True)
# Out:
# C:\Users\jason\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df_clean_v1.behavioral_antiviral_meds.fillna()
# Out:
# 0.0

# %%
df_clean_v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21879 entries, 0 to 26705
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   respondent_id                21879 non-null  int64
#  1   behavioral_antiviral_meds    21879 non-null  float64
#  2   behavioral_avoidance         21879 non-null  float64
#  3   behavioral_face_mask         21879 non-null  float64
#  4   behavioral_wash_hands        21879 non-null  float64
#  5   behavioral_large_gatherings  21879 non-null  float64
#  6   behavioral_outside_home      21879 non-null  float64
#  7   behavioral_touch_face        21879 non-null  float64
#  8   doctor_recc_seasonal         21879 non-null  float64
#  9   chronic_med_condition        21879 non-null  float64
#  10  child_under_6_months         21879 non-null  float64
#  11  health_worker                21879 non-null  float64
# ...

# %%
df_clean_v1.columns
# Out:
# Index(['respondent_id', 'behavioral_antiviral_meds', 'behavioral_avoidance',
#        'behavioral_face_mask', 'behavioral_wash_hands',
#        'behavioral_large_gatherings', 'behavioral_outside_home',
#        'behavioral_touch_face', 'doctor_recc_seasonal',
#        'chronic_med_condition', 'child_under_6_months', 'health_worker',
#        'health_insurance', 'opinion_seas_vacc_effective', 'opinion_seas_risk',
#        'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex',
#        'income_poverty', 'marital_status', 'rent_or_own', 'employment_status',
#        'hhs_geo_region', 'census_msa', 'household_adults',
#        'household_children', 'seasonal_vaccine'],
#       dtype='object')

# %%
X = df_clean_v1.drop('seasonal_vaccine', axis=1)

# %%
def percent_plot(col):
    # Group the data by chosen column and 'seasonal_vaccine' and calculate the percentages
    grouped_data = df_clean_v1.groupby([col, 'seasonal_vaccine']).size() / df_clean_v1.groupby(col).size() * 100
    grouped_data = grouped_data.reset_index()
    grouped_data = grouped_data.rename(columns={0: 'Percentage'})

    # Create the bar plot
    sns.barplot(x=col, y='Percentage', hue='seasonal_vaccine', data=grouped_data)

    # Add labels and title
    plt.xlabel(col)
    plt.ylabel('Percentage')
    plt.title(f'Percentage of Vaccinated and Non-vaccinated by {col}')

    # Show the plot
    plt.show()

# %%
percent_plot('behavioral_antiviral_meds')

# %% [markdown]
# distributions aren't so different for people who took or didn't take antiviral meds

# %%
percent_plot('behavioral_avoidance')

# %% [markdown]
# behavioral_avoidance:  1 = has avoided close contact with those with flu-like symptoms
#
# It looks like among those who have not practiced avoidance, a larger proportion did not get the vaccine compared with those who do practice avoidance.

# %%
percent_plot('behavioral_face_mask')

# %% [markdown]
# ***** Among those who bought a face mask, actually more got the vaccine than didn't.  Among those who didn't buy one, more did not get the vaccine.

# %%
percent_plot('behavioral_wash_hands')

# %% [markdown]
#  Among those who don't frequently wash hands, way more didn't get the vaccine.  Among those who wash hands , it's comparable.

# %%
percent_plot('behavioral_large_gatherings')

# %% [markdown]
# among those who reduced time at large gatherings, a more got the vaccine than didn't.  Compared with those who don't avoid large gatherings, where more did not get the vax.

# %%
percent_plot('behavioral_outside_home')

# %% [markdown]
# similar

# %%
percent_plot('behavioral_touch_face')

# %% [markdown]
# similar

# %%
percent_plot('doctor_recc_seasonal')

# %%
percent_plot('chronic_med_condition')

# %%
percent_plot('child_under_6_months')

# %%
percent_plot('health_worker')

# %%
percent_plot('health_insurance')

# %%
percent_plot('opinion_seas_vacc_effective')

# %%
percent_plot('opinion_seas_risk')

# %%
percent_plot('opinion_seas_sick_from_vacc')

# %%
percent_plot('age_group')

# %%
percent_plot('education')

# %%
percent_plot('race')

# %%
percent_plot('sex')

# %%
percent_plot('income_poverty')

# %%
percent_plot('marital_status')

# %%
percent_plot('rent_or_own')

# %%
percent_plot('employment_status')

# %%
percent_plot('hhs_geo_region')

# %%
percent_plot('census_msa')

# %%
percent_plot('household_adults')

# %%
percent_plot('household_children')
